# %%
import pandas as pd

# %%
df = pd.read_csv('AgentPerformance- Agent Performance Report.csv')
dframe= pd.read_csv('Agent_Login_Report- Agent Login Report.csv')
df
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  30-07-2022        Prerna Singh           11
# 1         2  30-07-2022       Nandani Gupta           11
# 2         3  30-07-2022          Ameya Jain           14
# 3         4  30-07-2022       Mahesh Sarade           14
# 4         5  30-07-2022              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  01-07-2022   Sowmiya Sivakumar            0
# 2156   2157  01-07-2022             Nitin M            0
# 2157   2158  01-07-2022              Vivek             0
# 2158   2159  01-07-2022       Ayushi Mishra            0
# 2159   2160  01-07-2022  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %% [markdown]
# #**1.Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave**

# %% [markdown]
# **a)Week-1**

# %%
df1 = df.copy()
df1
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  30-07-2022        Prerna Singh           11
# 1         2  30-07-2022       Nandani Gupta           11
# 2         3  30-07-2022          Ameya Jain           14
# 3         4  30-07-2022       Mahesh Sarade           14
# 4         5  30-07-2022              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  01-07-2022   Sowmiya Sivakumar            0
# 2156   2157  01-07-2022             Nitin M            0
# 2157   2158  01-07-2022              Vivek             0
# 2158   2159  01-07-2022       Ayushi Mishra            0
# 2159   2160  01-07-2022  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
week1=df1[((df1['Date'] >= '01-07-2022') & (df1['Date'] <= '07-07-2022'))]
week1= week1[week1['Total Chats']>0]
week1.groupby(['Agent Name'])['Average Rating'].agg([('Present','count'),('Total','sum'), ('week1_average_rating','mean')])
# Out:
#                         Present  Total  week1_average_rating
# Agent Name
# Aditya Shinde                 5  21.42              4.284000
# Aditya_iot                    1   3.83              3.830000
# Ameya Jain                    1   4.00              4.000000
# Anirudh                       2   1.00              0.500000
# Ankitjha                      1   5.00              5.000000
# Anurag Tiwari                 1   2.00              2.000000
# Aravind                       1   4.93              4.930000
# Ashad Nasim                   2   5.00              2.500000
# Ayushi Mishra                 5  21.78              4.356000
# Bharath                       5  23.37              4.674000
# Boktiar Ahmed Bappy           7  31.94              4.562857
# Deepranjan Gupta              5  21.28              4.256000
# Dibyanshu                     1   0.00              0.000000
# Harikrishnan Shaji            1   1.00              1.000000
# ...

# %% [markdown]
# **b) Week-2**

# %%
week2=df1[((df1['Date'] >= '08-07-2022') & (df1['Date'] <= '14-07-2022'))]
week2= week2[week2['Total Chats']>0]
week2.groupby(['Agent Name'])['Average Rating'].agg([('Present','count'),('Total','sum'), ('week2_average_rating','mean')])
# Out:
#                         Present  Total  week2_average_rating
# Agent Name
# Aditya Shinde                 5  23.68              4.736000
# Aditya_iot                    5  21.77              4.354000
# Ameya Jain                    2   8.96              4.480000
# Anirudh                       5  18.35              3.670000
# Anurag Tiwari                 1   3.50              3.500000
# Aravind                       6  28.32              4.720000
# Ayushi Mishra                 5  21.80              4.360000
# Bharath                       5  23.05              4.610000
# Boktiar Ahmed Bappy           3  14.13              4.710000
# Deepranjan Gupta              5  22.17              4.434000
# Harikrishnan Shaji            7  29.41              4.201429
# Hrisikesh Neogi               5  22.68              4.536000
# Ishawant Kumar                7  31.71              4.530000
# Jawala Prakash                4  17.37              4.342500
# ...

# %% [markdown]
# **c) Week-3**

# %%
week3=df1[((df1['Date'] >= '15-07-2022') & (df1['Date'] <= '21-07-2022'))]
week3= week3[week3['Total Chats']>0]
week3.groupby(['Agent Name'])['Average Rating'].agg([('Present','count'),('Total','sum'), ('week3_average_rating','mean')])
# Out:
#                         Present  Total  week3_average_rating
# Agent Name
# Aditya Shinde                 2   8.91              4.455000
# Aditya_iot                    5  20.33              4.066000
# Ameya Jain                    6  26.01              4.335000
# Aravind                       4  18.68              4.670000
# Ayushi Mishra                 6  24.63              4.105000
# Bharath                       3  14.29              4.763333
# Boktiar Ahmed Bappy           7  28.14              4.020000
# Deepranjan Gupta              4  11.77              2.942500
# Harikrishnan Shaji            5  22.29              4.458000
# Hitesh Choudhary              1   0.00              0.000000
# Hrisikesh Neogi               5  22.97              4.594000
# Ishawant Kumar                7  29.86              4.265714
# Jawala Prakash                6  24.17              4.028333
# Jaydeep Dixit                 5  23.24              4.648000
# ...

# %% [markdown]
# **d) Week-4**

# %%
week4=df1[((df1['Date'] >= '22-07-2022') & (df1['Date'] <= '28-07-2022'))]
week4= week4[week4['Total Chats']>0]
week4.groupby(['Agent Name'])['Average Rating'].agg([('Present','count'),('Total','sum'), ('week4_average_rating','mean')])
# Out:
#                         Present  Total  week4_average_rating
# Agent Name
# Aditya_iot                    5  19.83              3.966000
# Ameya Jain                    5  23.07              4.614000
# Ankitjha                      2   3.00              1.500000
# Aravind                       3  13.51              4.503333
# Ayushi Mishra                 7  31.25              4.464286
# Bharath                       5  23.95              4.790000
# Boktiar Ahmed Bappy           7  24.08              3.440000
# Chaitra K Hiremath            5  20.94              4.188000
# Deepranjan Gupta              5  22.52              4.504000
# Harikrishnan Shaji            5  21.92              4.384000
# Hrisikesh Neogi               4  18.02              4.505000
# Ishawant Kumar                7  30.89              4.412857
# Jawala Prakash                7  28.85              4.121429
# Jaydeep Dixit                 5  22.51              4.502000
# ...

# %% [markdown]
# **e) Week-5**

# %%
week5=df1[((df1['Date'] >= '29-07-2022') & (df1['Date'] <= '30-07-2022'))]
week5= week5[week5['Total Chats']>0]
week5.groupby(['Agent Name'])['Average Rating'].agg([('Present','count'),('Total','sum'), ('week5_average_rating','mean')])
# Out:
#                         Present  Total  week5_average_rating
# Agent Name
# Aditya_iot                    1   4.60                 4.600
# Ameya Jain                    1   4.55                 4.550
# Ayushi Mishra                 1   5.00                 5.000
# Bharath                       1   4.85                 4.850
# Boktiar Ahmed Bappy           2   8.75                 4.375
# Chaitra K Hiremath            1   5.00                 5.000
# Deepranjan Gupta              2   8.86                 4.430
# Harikrishnan Shaji            1   4.57                 4.570
# Hrisikesh Neogi               2   8.07                 4.035
# Ishawant Kumar                2   9.67                 4.835
# Jawala Prakash                2   7.83                 3.915
# Jaydeep Dixit                 1   3.95                 3.950
# Khushboo Priya                1   4.43                 4.430
# Madhulika G                   2   8.61                 4.305
# ...

# %% [markdown]
# #**2.Total working days for each agents.**

# %%
df2 = df1.copy()
work_days = df2[df2['Total Chats']>0] 
work_days.groupby(['Agent Name'])['Date'].agg([('Working_days','count')])
# Out:
#                         Working_days
# Agent Name
# Aditya Shinde                     12
# Aditya_iot                        17
# Ameya Jain                        15
# Anirudh                            7
# Ankitjha                           3
# Anurag Tiwari                      2
# Aravind                           14
# Ashad Nasim                        2
# Ayushi Mishra                     24
# Bharath                           19
# Boktiar Ahmed Bappy               26
# Chaitra K Hiremath                 6
# Deepranjan Gupta                  21
# Dibyanshu                          1
# Harikrishnan Shaji                19
# Hitesh Choudhary                   1
# Hrisikesh Neogi                   21
# Ishawant Kumar                    24
# Jawala Prakash                    25
# Jayant Kumar                       8
# Jaydeep Dixit                     21
# Khushboo Priya                    26
# Madhulika G                       24
# Mahak                              1
# ...

# %% [markdown]
# #**3. Total query that agents have taken**

# %%
df3 = df.copy()
df3.groupby(['Agent Name'])['Total Chats'].agg([('Total_query','sum')])
# Out:
#                Total_query
# Agent Name
# Abhishek                 0
# Aditya                   0
# Aditya Shinde          277
# Aditya_iot             231
# Amersh                   0
# ...                    ...
# Uday Mishra              0
# Vasanth P                0
# Vivek                   44
# Wasim                  433
# Zeeshan                542
#
# [70 rows x 1 columns]

# %% [markdown]
# #**4. Total Feedback that you have received**

# %%
df4 = df.copy()
df4.groupby(['Agent Name'])['Total Feedback'].agg([('Total_feedback','sum')])
# Out:
#                Total_feedback
# Agent Name
# Abhishek                    0
# Aditya                      0
# Aditya Shinde             153
# Aditya_iot                131
# Amersh                      0
# ...                       ...
# Uday Mishra                 0
# Vasanth P                   0
# Vivek                      20
# Wasim                     284
# Zeeshan                   335
#
# [70 rows x 1 columns]

# %% [markdown]
# #**5. A agent name who have average rating between 3.5 to 4**

# %%
df5 = df.copy()
df5 = df5[df5['Total Chats']>0] 
df5 = df5.groupby(['Agent Name'])['Average Rating'].agg([len, sum])
df5['month_avg_rating']=df5['sum']/df5['len']
df5[((df5.month_avg_rating<4)& (df5.month_avg_rating >3.5))]
df5['month_avg_rating']
# Out:
# Agent Name
# Aditya Shinde             4.500833
# Aditya_iot                4.138824
# Ameya Jain                4.439333
# Anirudh                   2.764286
# Ankitjha                  2.666667
# Anurag Tiwari             2.750000
# Aravind                   4.674286
# Ashad Nasim               2.500000
# Ayushi Mishra             4.352500
# Bharath                   4.711053
# Boktiar Ahmed Bappy       4.116923
# Chaitra K Hiremath        4.323333
# Deepranjan Gupta          4.123810
# Dibyanshu                 0.000000
# Harikrishnan Shaji        4.167895
# Hitesh Choudhary          0.000000
# Hrisikesh Neogi           4.480476
# Ishawant Kumar            4.429167
# Jawala Prakash            4.166400
# Jayant Kumar              4.007500
# Jaydeep Dixit             4.524286
# Khushboo Priya            4.273462
# Madhulika G               4.373333
# Mahak                     3.000000
# Mahesh Sarade             4.000556
# Maitry                    4.390500
# ...

# %% [markdown]
# #**6. Agent name who have rating less then 3.5**

# %%
df6 =df.copy()
df6 = df6[df6['Average Rating']<3.5]
df6[['Agent Name', 'Average Rating']]
# Out:
#               Agent Name  Average Rating
# 1          Nandani Gupta            3.14
# 19      Hitesh Choudhary            0.00
# 20            Sanjeevan             0.00
# 21              Anirudh             0.00
# 22      Shiva Srivastava            0.00
# ...                  ...             ...
# 2155   Sowmiya Sivakumar            0.00
# 2156             Nitin M            0.00
# 2157              Vivek             0.00
# 2158       Ayushi Mishra            0.00
# 2159  Chaitra K Hiremath            0.00
#
# [1474 rows x 2 columns]

# %% [markdown]
# #**7. agent name who have rating more then 4.5**

# %%
df7 =df.copy()
df7 = df7[df7['Average Rating']>4.5]
df7[['Agent Name', 'Average Rating']]
# Out:
#               Agent Name  Average Rating
# 2             Ameya Jain            4.55
# 3          Mahesh Sarade            4.71
# 5                Mukesh             4.62
# 6        Saikumarreddy N            5.00
# 7          Sanjeev Kumar            5.00
# ...                  ...             ...
# 2100      Shubham Sharma            5.00
# 2101       Jaydeep Dixit            4.77
# 2102  Shivananda Sonwane            4.86
# 2103      Khushboo Priya            4.61
# 2104     Hrisikesh Neogi            4.56
#
# [307 rows x 2 columns]

# %% [markdown]
# #**8. How many feedaback agents have received more then 4.5 average**

# %%
df8 = df.copy()
df8 = df8[df8['Average Rating']>4.5]
df8[df8['Agent Name']=='Aditya Shinde']
df8.groupby(['Agent Name'])['Total Feedback'].sum()
# Out:
# Agent Name
# Aditya Shinde              73
# Aditya_iot                 43
# Ameya Jain                150
# Anirudh                     2
# Ankitjha                    1
# Aravind                   178
# Ayushi Mishra              75
# Bharath                   231
# Boktiar Ahmed Bappy        52
# Chaitra K Hiremath          5
# Deepranjan Gupta           83
# Harikrishnan Shaji         80
# Hrisikesh Neogi           183
# Ishawant Kumar             79
# Jawala Prakash             33
# Jayant Kumar                7
# Jaydeep Dixit             179
# Khushboo Priya            134
# Madhulika G                67
# Mahesh Sarade              46
# Maitry                     81
# Manjunatha A              132
# Mithun S                   93
# Mukesh                     17
# Mukesh Rao                  1
# Muskan Garg                14
# Nandani Gupta              91
# Nishtha Jain               18
# Prabir Kumar Satapathy     53
# Prateek _iot               54
# ...

# %% [markdown]
# #**9. Average weekly response time for each agent**

# %%
df9 = df.copy()
df9 = df9[df9['Total Chats']>0]
df9[['hour','minute', 'seconds']]=df9['Average Response Time'].str.split(":", expand =True)
df9[['hour','minute', 'seconds']]= df9[['hour','minute', 'seconds']].apply(pd.to_numeric)
df9['total_time'] = df9['hour']*3600+ df9['minute']*60 +df9['seconds']
df9
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  30-07-2022        Prerna Singh           11
# 1         2  30-07-2022       Nandani Gupta           11
# 2         3  30-07-2022          Ameya Jain           14
# 3         4  30-07-2022       Mahesh Sarade           14
# 4         5  30-07-2022              Swati            14
# ...     ...         ...                 ...          ...
# 2101   2102  01-07-2022       Jaydeep Dixit           25
# 2102   2103  01-07-2022  Shivananda Sonwane           23
# 2103   2104  01-07-2022      Khushboo Priya           24
# 2104   2105  01-07-2022     Hrisikesh Neogi           15
# 2105   2106  01-07-2022              Tarun            22
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
df9_week1 = df9[(df9['Date']>='01-07-2022') & (df9['Date']<='07-07-2022') ]
df9_week1.groupby(['Agent Name'])['total_time'].agg([('week1_average_response_time','mean')])
# Out:
#                         week1_average_response_time
# Agent Name
# Aditya Shinde                             76.200000
# Aditya_iot                               109.000000
# Ameya Jain                                 0.000000
# Anirudh                                   62.500000
# Ankitjha                                   0.000000
# Anurag Tiwari                              0.000000
# Aravind                                   39.000000
# Ashad Nasim                              579.500000
# Ayushi Mishra                             69.600000
# Bharath                                   36.800000
# Boktiar Ahmed Bappy                       54.714286
# Deepranjan Gupta                          77.000000
# Dibyanshu                                 38.000000
# Harikrishnan Shaji                        57.000000
# Hrisikesh Neogi                           66.600000
# Ishawant Kumar                           107.000000
# Jawala Prakash                           139.166667
# ...

# %%
df9_week2 = df9[(df9['Date']>='08-07-2022') & (df9['Date']<='14-07-2022') ]
df9_week2.groupby(['Agent Name'])['total_time'].agg([('week2_average_response_time','mean')])

# %%
df9_week3 = df9[(df9['Date']>='15-07-2022') & (df9['Date']<='21-07-2022') ]
df9_week3.groupby(['Agent Name'])['total_time'].agg([('week3_average_response_time','mean')])

# %%
df9_week4 = df9[(df9['Date']>='22-07-2022') & (df9['Date']<='28-07-2022') ]
df9_week4.groupby(['Agent Name'])['total_time'].agg([('week4_average_response_time','mean')])

# %%
df9_week5 = df9[(df9['Date']>='29-07-2022') & (df9['Date']<='30-07-2022') ]
df9_week5.groupby(['Agent Name'])['total_time'].agg([('week5_average_response_time','mean')])
# Out:
#                         week5_average_response_time
# Agent Name
# Aditya_iot                                     52.0
# Ameya Jain                                     30.0
# Ayushi Mishra                                  76.0
# Bharath                                        28.0
# Boktiar Ahmed Bappy                           131.0
# Chaitra K Hiremath                             41.0
# Deepranjan Gupta                               40.5
# Harikrishnan Shaji                             42.0
# Hrisikesh Neogi                                94.0
# Ishawant Kumar                                 34.0
# Jawala Prakash                                 86.0
# Jaydeep Dixit                                  52.0
# Khushboo Priya                                 92.0
# Madhulika G                                    93.5
# Mahesh Sarade                                  90.5
# Manjunatha A                                   47.0
# Mithun S                                       49.5
# ...

# %% [markdown]
# #**10.average weekely resolution time for each agents**

# %%
df10= df.copy()
df10 = df10[df10['Total Chats']>0]
df10[['hour','minute', 'seconds']]=df10['Average Resolution Time'].str.split(":", expand =True)
df10[['hour','minute', 'seconds']]= df10[['hour','minute', 'seconds']].apply(pd.to_numeric)
df10['total_time'] = df10['hour']*3600+ df10['minute']*60 +df10['seconds']
df10
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  30-07-2022        Prerna Singh           11
# 1         2  30-07-2022       Nandani Gupta           11
# 2         3  30-07-2022          Ameya Jain           14
# 3         4  30-07-2022       Mahesh Sarade           14
# 4         5  30-07-2022              Swati            14
# ...     ...         ...                 ...          ...
# 2101   2102  01-07-2022       Jaydeep Dixit           25
# 2102   2103  01-07-2022  Shivananda Sonwane           23
# 2103   2104  01-07-2022      Khushboo Priya           24
# 2104   2105  01-07-2022     Hrisikesh Neogi           15
# 2105   2106  01-07-2022              Tarun            22
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
df10_week1 = df10[(df10['Date']>='01-07-2022') & (df10['Date']<='07-07-2022') ]
df10_week1.groupby(['Agent Name'])['total_time'].agg([('week1_average_response_time','mean')])
# Out:
#                         week1_average_response_time
# Agent Name
# Aditya Shinde                                  6569
# Aditya_iot                                     1520
# Ameya Jain                                      107
# Anirudh                                        1346
# Ankitjha                                       1282
# Anurag Tiwari                                   169
# Aravind                                        1281
# Ashad Nasim                                     628
# Ayushi Mishra                                  5800
# Bharath                                        4546
# Boktiar Ahmed Bappy                            5973
# Deepranjan Gupta                               9479
# Dibyanshu                                       740
# Harikrishnan Shaji                              603
# Hrisikesh Neogi                                6132
# Ishawant Kumar                                 1710
# Jawala Prakash                                 4602
# ...

# %%
df10_week2 = df10[(df10['Date']>='08-07-2022') & (df10['Date']<='14-07-2022') ]
df10_week2.groupby(['Agent Name'])['total_time'].agg([('week2_average_response_time','mean')])
# Out:
#                         week2_average_response_time
# Agent Name
# Aditya Shinde                           1555.000000
# Aditya_iot                              1107.800000
# Ameya Jain                               927.500000
# Anirudh                                  843.600000
# Anurag Tiwari                           2049.000000
# Aravind                                 1178.000000
# Ayushi Mishra                           1293.200000
# Bharath                                  980.400000
# Boktiar Ahmed Bappy                     3771.666667
# Deepranjan Gupta                        2201.600000
# Harikrishnan Shaji                       896.285714
# Hrisikesh Neogi                         1030.800000
# Ishawant Kumar                          1137.857143
# Jawala Prakash                          1265.000000
# Jayant Kumar                            1133.666667
# Jaydeep Dixit                           1794.800000
# Khushboo Priya                           832.857143
# ...

# %%
df10_week3 = df10[(df10['Date']>='15-07-2022') & (df10['Date']<='21-07-2022') ]
df10_week3.groupby(['Agent Name'])['total_time'].agg([('week3_average_response_time','mean')])
# Out:
#                         week3_average_response_time
# Agent Name
# Aditya Shinde                           2137.500000
# Aditya_iot                               980.400000
# Ameya Jain                               631.000000
# Aravind                                 1261.000000
# Ayushi Mishra                           1075.833333
# Bharath                                  808.000000
# Boktiar Ahmed Bappy                      718.857143
# Deepranjan Gupta                        2047.000000
# Harikrishnan Shaji                      1337.200000
# Hitesh Choudhary                          85.000000
# Hrisikesh Neogi                         1508.400000
# Ishawant Kumar                           980.142857
# Jawala Prakash                           826.833333
# Jaydeep Dixit                           1655.200000
# Khushboo Priya                           884.000000
# Madhulika G                             1291.200000
# Mahesh Sarade                            801.200000
# ...

# %%
df10_week4 = df10[(df10['Date']>='22-07-2022') & (df10['Date']<='28-07-2022') ]
df10_week4.groupby(['Agent Name'])['total_time'].agg([('week4_average_response_time','mean')])
# Out:
#                         week4_average_response_time
# Agent Name
# Aditya_iot                               983.200000
# Ameya Jain                               682.200000
# Ankitjha                                 176.000000
# Aravind                                  891.333333
# Ayushi Mishra                           1237.285714
# Bharath                                 1218.800000
# Boktiar Ahmed Bappy                      960.285714
# Chaitra K Hiremath                       438.200000
# Deepranjan Gupta                        1484.200000
# Harikrishnan Shaji                      1048.200000
# Hrisikesh Neogi                         1275.000000
# Ishawant Kumar                          1118.428571
# Jawala Prakash                           958.142857
# Jaydeep Dixit                           1491.200000
# Khushboo Priya                          1113.333333
# Madhulika G                             1188.600000
# Mahesh Sarade                           1047.200000
# ...

# %%
df10_week5 = df10[(df10['Date']>='29-07-2022') & (df10['Date']<='30-07-2022') ]
df10_week5.groupby(['Agent Name'])['total_time'].agg([('week5_average_response_time','mean')])
# Out:
#                         week5_average_response_time
# Agent Name
# Aditya_iot                                    802.0
# Ameya Jain                                    696.0
# Ayushi Mishra                                 296.0
# Bharath                                      1462.0
# Boktiar Ahmed Bappy                           836.5
# Chaitra K Hiremath                            478.0
# Deepranjan Gupta                              719.5
# Harikrishnan Shaji                           1549.0
# Hrisikesh Neogi                              1930.5
# Ishawant Kumar                                794.0
# Jawala Prakash                               1041.5
# Jaydeep Dixit                                1453.0
# Khushboo Priya                               1295.0
# Madhulika G                                  2036.5
# Mahesh Sarade                                1275.5
# Manjunatha A                                 2576.0
# Mithun S                                      757.0
# ...

# %% [markdown]
# #**11. list of all agents name**

# %%
df11 = df.copy()
df11['Agent Name'].unique()
# Out:
# array(['Prerna Singh', 'Nandani Gupta', 'Ameya Jain', 'Mahesh Sarade',
#        'Swati ', 'Mukesh ', 'Saikumarreddy N', 'Sanjeev Kumar',
#        'Shubham Sharma', 'Nishtha Jain', 'Manjunatha A', 'Khushboo Priya',
#        'Suraj S Bilgi', 'Harikrishnan Shaji', 'Hrisikesh Neogi',
#        'Shivan K', 'Sowmiya Sivakumar', 'Madhulika G', 'Mithun S',
#        'Hitesh Choudhary', 'Sanjeevan ', 'Anirudh ', 'Shiva Srivastava',
#        'Dibyanshu ', 'Ashish ', 'Uday Mishra', 'Aditya Shinde',
#        'Jayant Kumar', 'Aditya_iot ', 'Prabir Kumar Satapathy',
#        'Saurabh Shukla', 'Wasim ', 'Samprit ', 'Maitry ', 'Abhishek ',
#        'Rishav Dash', 'Aravind ', 'Tarun ', 'Muskan Garg', 'Ankit Sharma',
#        'Bharath ', 'Ashad Nasim', 'Vasanth P', 'Aditya ', 'Amersh ',
#        'Sandipan Saha', 'Ineuron Intelligence ', 'Mahak ', 'Mukesh Rao ',
#        'Zeeshan ', 'Anurag Tiwari', 'Ankitjha ', 'Saif Khan',
#        'Jaydeep Dixit', 'Sudhanshu Kumar', 'Maneesh ', 'Hyder Abbas',
# ...

# %%
df.head(1)
# Out:
#    SL No        Date    Agent Name  Total Chats Average Response Time  \
# 0      1  30-07-2022  Prerna Singh           11              00:00:38
#
#   Average Resolution Time  Average Rating  Total Feedback
# 0                00:04:20            4.11               9

# %% [markdown]
# #**12. Percentage of chat on which they have received a feedback**

# %%
df12 = df.copy()
df12= df12.groupby(['Agent Name'])[['Total Chats', 'Total Feedback']].sum()
df12.drop(df12.index[df12['Total Chats'] == 0], inplace = True)
df12['percentage'] =100* df12['Total Feedback']/df12['Total Chats']
df12
# Out:
#                         Total Chats  Total Feedback  percentage
# Agent Name
# Aditya Shinde                   277             153   55.234657
# Aditya_iot                      231             131   56.709957
# Ameya Jain                      322             228   70.807453
# Anirudh                          81              39   48.148148
# Ankitjha                          5               3   60.000000
# Anurag Tiwari                     4               3   75.000000
# Aravind                         366             233   63.661202
# Ashad Nasim                      18               9   50.000000
# Ayushi Mishra                   514             329   64.007782
# Bharath                         369             247   66.937669
# Boktiar Ahmed Bappy             452             311   68.805310
# Chaitra K Hiremath               64              37   57.812500
# Deepranjan Gupta                493             312   63.286004
# ...

# %% [markdown]
# #**13 Total contributation hour for each and every agents weekly basis**

# %%
df13 = dframe.copy()
df13 = df13.reset_index(drop=True)
df13[['hour','minute', 'second']]= df13['Duration'].str.split(':', expand = True).apply(pd.to_numeric)
df13['total_contribution(in min)'] = df13['hour']*60+df13['minute'] +df13['second']/60
df13.head()
# Out:
#    SL No               Agent       Date  Login Time Logout Time  Duration  \
# 0      1  Shivananda Sonwane  30-Jul-22  3:35:29 PM  5:39:39 PM  02:04:10
# 1      2      Khushboo Priya  30-Jul-22  3:06:59 PM  3:07:16 PM  00:00:17
# 2      3       Nandani Gupta  30-Jul-22  3:04:24 PM  5:31:07 PM  02:26:42
# 3      4     Hrisikesh Neogi  30-Jul-22  2:34:29 PM  3:19:35 PM  00:45:06
# 4      5             Mukesh   30-Jul-22  2:03:15 PM  3:11:52 PM  01:08:36
#
#    hour  minute  second  total_contribution(in min)
# 0     2       4      10                  124.166667
# 1     0       0      17                    0.283333
# 2     2      26      42                  146.700000
# 3     0      45       6                   45.100000
# 4     1       8      36                   68.600000

# %% [markdown]
# **a) week-1: Contribution**

# %%
df13[(df13['Date']>='01-07-2022')&(df13['Date']<='07-07-2022')].groupby('Agent')['total_contribution(in min)'].agg([('week1_contribution','sum')])
# Out:
#         week1_contribution
# Agent
# Tarun         30848.333333

# %% [markdown]
# **b) week-2: Contribution**

# %%
df13[(df13['Date']>='08-07-2022')&(df13['Date']<='14-07-2022')].groupby('Agent')['total_contribution(in min)'].agg([('week2_contribution','sum')])
# Out:
# Empty DataFrame
# Columns: [week2_contribution]
# Index: []

# %% [markdown]
# **c) week-3: Contribution**

# %%
df13[(df13['Date']>='15-07-2022')&(df13['Date']<='21-07-2022')].groupby('Agent')['total_contribution(in min)'].agg([('week3_contribution','sum')])
# Out:
#                        week3_contribution
# Agent
# Aditya_iot                     121.433333
# Ameya Jain                     395.733333
# Anurag Tiwari                    0.666667
# Aravind                        383.416667
# Bharath                        360.716667
# Boktiar Ahmed Bappy            358.000000
# Deepranjan Gupta               108.716667
# Dibyanshu                      373.250000
# Harikrishnan Shaji             374.433333
# Hrisikesh Neogi                503.700000
# Ineuron Intelligence            86.916667
# Ishawant Kumar                 378.816667
# Jawala Prakash                 358.116667
# Khushboo Priya                 358.066667
# Madhulika G                    360.650000
# Mahesh Sarade                  407.166667
# Maitry                         369.950000
# Manjunatha A                   358.616667
# Mithun S                       182.500000
# Nandani Gupta                  358.200000
# Nishtha Jain                   349.583333
# ...

# %% [markdown]
# **d) week-4: Contribution**

# %%
df13[(df13['Date']>='22-07-2022')&(df13['Date']<='28-07-2022')].groupby('Agent')['total_contribution(in min)'].agg([('week4_contribution','sum')])
# Out:
#                         week4_contribution
# Agent
# Aditya Shinde                     2.166667
# Aditya_iot                      509.483333
# Amersh                          181.166667
# Ameya Jain                     1491.983333
# Ankitjha                        136.016667
# Anurag Tiwari                    63.083333
# Aravind                        1050.383333
# Ayushi Mishra                  1558.533333
# Bharath                        1423.300000
# Boktiar Ahmed Bappy            1704.750000
# Chaitra K Hiremath             1152.700000
# Deepranjan Gupta               4040.216667
# Dibyanshu                      1613.416667
# Harikrishnan Shaji             1564.533333
# Hrisikesh Neogi                1492.416667
# Hyder Abbas                      23.283333
# Ishawant Kumar                 1373.283333
# Jawala Prakash                 1433.950000
# Jaydeep Dixit                  2517.016667
# Khushboo Priya                 1604.783333
# Madhulika G                    1735.883333
# ...

# %% [markdown]
# **e) week-5: Contribution**

# %%
df13[(df13['Date']>='29-07-2022')&(df13['Date']<='30-07-2022')].groupby('Agent')['total_contribution(in min)'].agg([('week5_contribution','sum')])
# Out:
#                         week5_contribution
# Agent
# Aditya_iot                      132.083333
# Anurag Tiwari                    56.966667
# Ayushi Mishra                   147.900000
# Bharath                         363.483333
# Boktiar Ahmed Bappy             310.883333
# Chaitra K Hiremath              446.266667
# Deepranjan Gupta                602.433333
# Dibyanshu                       573.333333
# Hrisikesh Neogi                 756.750000
# Ishawant Kumar                  548.450000
# Jawala Prakash                  363.266667
# Jaydeep Dixit                   349.216667
# Madhulika G                     346.583333
# Mahesh Sarade                   366.366667
# Mithun S                        356.333333
# Mukesh                          465.700000
# Muskan Garg                     138.100000
# Nandani Gupta                   353.433333
# Prabir Kumar Satapathy          382.900000
# Prateek _iot                    141.916667
# Prerna Singh                    332.250000
# ...

# %% [markdown]
# #**14. Total percentage of active hour for a month**
#
# **#Assuming employee work 5 days in a week and 8 hours a day**
# ( 30 days dedicated hours for an employee = 40*2/56+20*8 = 161.43)

# %%
df14 = dframe.copy()
df14 = df14.reset_index(drop=True)
df14[['hour','minute', 'second']]= df14['Duration'].str.split(':', expand = True).apply(pd.to_numeric)
df14['total_contribution(in hr)'] = df14['hour']+df14['minute']/60 +df14['second']/3660
df15= df14.groupby('Agent')['total_contribution(in hr)'].agg([('month_contribution','sum')])
df15['percent_active'] = 100*df15['month_contribution']/161.43
df15
# Out:
#                         month_contribution  percent_active
# Agent
# Aditya Shinde                     0.036066        0.022341
# Aditya_iot                       15.729781        9.744026
# Amersh                            3.063115        1.897488
# Ameya Jain                       42.074044       26.063336
# Ankitjha                          2.266393        1.403948
# Anurag Tiwari                     2.775410        1.719265
# Aravind                          24.298087       15.051779
# Ayushi Mishra                    38.119399       23.613578
# Bharath                          48.075137       29.780795
# Boktiar Ahmed Bappy              40.266667       24.943732
# Chaitra K Hiremath               34.323770       21.262325
# Deepranjan Gupta                106.268579       65.829511
# Dibyanshu                        52.581694       32.572443
# Harikrishnan Shaji               53.711202       33.272132
# Hrisikesh Neogi                  57.563661       35.658590
# ...
